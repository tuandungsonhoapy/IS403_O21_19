# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv('/content/SONY.csv')
df_reversed = df.loc[::-1].reset_index(drop=True)
df1=df.reset_index()['Close']
features = df_reversed[['Open', 'High', 'Low', 'Close']].values

# %%
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.8 * len(df1))
test_size = int(0.2 * len(df1))

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# Xây dựng mô hình RNN
rnn_model = Sequential()
rnn_model.add(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2])))
rnn_model.add(Dense(32, activation='relu'))
rnn_model.add(Dense(1))

# %%
# Biên dịch mô hình
rnn_model.compile(optimizer='adam', loss='mse')

# %%
# Huấn luyện mô hình RNN
rnn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 36/36 [==============================] - 5s 58ms/step - loss: 0.0618 - val_loss: 0.0060
# Epoch 2/50
# 36/36 [==============================] - 1s 41ms/step - loss: 0.0024 - val_loss: 9.8110e-04
# Epoch 3/50
# 36/36 [==============================] - 2s 43ms/step - loss: 0.0010 - val_loss: 7.9090e-04
# Epoch 4/50
# 36/36 [==============================] - 1s 40ms/step - loss: 9.9692e-04 - val_loss: 7.9715e-04
# Epoch 5/50
# 36/36 [==============================] - 1s 41ms/step - loss: 9.5670e-04 - val_loss: 7.4530e-04
# Epoch 6/50
# 36/36 [==============================] - 1s 41ms/step - loss: 8.9496e-04 - val_loss: 7.0412e-04
# Epoch 7/50
# 36/36 [==============================] - 2s 58ms/step - loss: 8.6265e-04 - val_loss: 6.5407e-04
# Epoch 8/50
# 36/36 [==============================] - 3s 72ms/step - loss: 8.2895e-04 - val_loss: 6.3080e-04
# Epoch 9/50
# 36/36 [==============================] - 1s 41ms/step - loss: 7.8374e-04 - val_loss: 5.9423e-04
# Epoch 10/50
# 36/36 [==============================] - 1s 41ms/step - loss: 8.0636e-04 - val_loss: 5.6262e-04
# Epoch 11/50
# 36/36 [==============================] - 1s 41ms/step - loss: 7.6149e-04 - val_loss: 5.4234e-04
# Epoch 12/50
# 36/36 [==============================] - 1s 42ms/step - loss: 7.5134e-04 - val_loss: 6.2840e-04
# Epoch 13/50
# 36/36 [==============================] - 1s 42ms/step - loss: 7.7521e-04 - val_loss: 6.1937e-04
# Epoch 14/50
# 36/36 [==============================] - 1s 41ms/step - loss: 7.0594e-04 - val_loss: 4.9681e-04
# Epoch 15/50
# 36/36 [==============================] - 2s 49ms/step - loss: 6.3375e-04 - val_loss: 4.5755e-04
# Epoch 16/50
# 36/36 [==============================] - 3s 71ms/step - loss: 6.2813e-04 - val_loss: 4.7287e-04
# Epoch 17/50
# 36/36 [==============================] - 2s 49ms/step - loss: 5.9286e-04 - val_loss: 4.1745e-04
# Epoch 18/50
# 36/36 [==============================] - 1s 41ms/step - loss: 6.0495e-04 - val_loss: 4.2137e-04
# Epoch 19/50
# 36/36 [==============================] - 2s 42ms/step - loss: 6.2032e-04 - val_loss: 4.0338e-04
# Epoch 20/50
# 36/36 [==============================] - 1s 40ms/step - loss: 6.0977e-04 - val_loss: 4.0608e-04
# Epoch 21/50
# 36/36 [==============================] - 2s 43ms/step - loss: 6.1396e-04 - val_loss: 5.1604e-04
# Epoch 22/50
# 36/36 [==============================] - 1s 41ms/step - loss: 7.2020e-04 - val_loss: 3.9959e-04
# Epoch 23/50
# 36/36 [==============================] - 1s 42ms/step - loss: 6.3236e-04 - val_loss: 5.1264e-04
# Epoch 24/50
# 36/36 [==============================] - 2s 67ms/step - loss: 5.4760e-04 - val_loss: 3.8916e-04
# Epoch 25/50
# 36/36 [==============================] - 2s 55ms/step - loss: 5.1615e-04 - val_loss: 3.8470e-04
# Epoch 26/50
# 36/36 [==============================] - 1s 42ms/step - loss: 5.0582e-04 - val_loss: 4.7533e-04
# Epoch 27/50
# 36/36 [==============================] - 1s 41ms/step - loss: 5.2194e-04 - val_loss: 3.6825e-04
# Epoch 28/50
# 36/36 [==============================] - 1s 41ms/step - loss: 5.1448e-04 - val_loss: 3.9154e-04
# Epoch 29/50
# 36/36 [==============================] - 1s 41ms/step - loss: 5.1339e-04 - val_loss: 3.5910e-04
# Epoch 30/50
# 36/36 [==============================] - 1s 40ms/step - loss: 4.9871e-04 - val_loss: 4.8959e-04
# Epoch 31/50
# 36/36 [==============================] - 1s 41ms/step - loss: 5.1539e-04 - val_loss: 3.5263e-04
# Epoch 32/50
# 36/36 [==============================] - 2s 63ms/step - loss: 4.8596e-04 - val_loss: 3.6891e-04
# Epoch 33/50
# 36/36 [==============================] - 2s 64ms/step - loss: 4.7865e-04 - val_loss: 3.6947e-04
# Epoch 34/50
# 36/36 [==============================] - 1s 41ms/step - loss: 4.8104e-04 - val_loss: 4.1820e-04
# Epoch 35/50
# 36/36 [==============================] - 1s 41ms/step - loss: 5.1971e-04 - val_loss: 4.1708e-04
# Epoch 36/50
# 36/36 [==============================] - 1s 41ms/step - loss: 4.9092e-04 - val_loss: 3.3799e-04
# Epoch 37/50
# 36/36 [==============================] - 1s 41ms/step - loss: 5.6189e-04 - val_loss: 3.3724e-04
# Epoch 38/50
# 36/36 [==============================] - 2s 42ms/step - loss: 4.7225e-04 - val_loss: 3.5594e-04
# Epoch 39/50
# 36/36 [==============================] - 1s 41ms/step - loss: 4.6839e-04 - val_loss: 3.3149e-04
# Epoch 40/50
# 36/36 [==============================] - 2s 57ms/step - loss: 4.7856e-04 - val_loss: 5.0830e-04
# Epoch 41/50
# 36/36 [==============================] - 3s 71ms/step - loss: 5.0722e-04 - val_loss: 3.9855e-04
# Epoch 42/50
# 36/36 [==============================] - 1s 40ms/step - loss: 4.9520e-04 - val_loss: 4.0693e-04
# Epoch 43/50
# 36/36 [==============================] - 1s 41ms/step - loss: 4.7809e-04 - val_loss: 3.4297e-04
# Epoch 44/50
# 36/36 [==============================] - 1s 41ms/step - loss: 4.8930e-04 - val_loss: 4.1102e-04
# Epoch 45/50
# 36/36 [==============================] - 1s 41ms/step - loss: 5.1366e-04 - val_loss: 3.2640e-04
# Epoch 46/50
# 36/36 [==============================] - 1s 41ms/step - loss: 4.6286e-04 - val_loss: 4.3451e-04
# Epoch 47/50
# 36/36 [==============================] - 1s 41ms/step - loss: 4.5249e-04 - val_loss: 3.1924e-04
# Epoch 48/50
# 36/36 [==============================] - 2s 47ms/step - loss: 4.6859e-04 - val_loss: 3.1927e-04
# Epoch 49/50
# 36/36 [==============================] - 3s 74ms/step - loss: 5.1503e-04 - val_loss: 3.2631e-04
# Epoch 50/50
# 36/36 [==============================] - 2s 46ms/step - loss: 4.4972e-04 - val_loss: 3.2818e-04

# %%
# Trích xuất các đặc trưng từ tầng cuối cùng của RNN
train_features_rnn = rnn_model.predict(X_train)
test_features_rnn = rnn_model.predict(X_test)
# Out:
# 45/45 [==============================] - 1s 14ms/step
# 9/9 [==============================] - 0s 14ms/step

# %%
# Kết hợp các đặc trưng từ RNN với các đặc trưng khác (ở đây chỉ dùng các đặc trưng từ RNN)
X_train_combined = train_features_rnn
X_test_combined = test_features_rnn

# %%
X_train_combined.shape
X_test_combined.shape
# Out:
# (283, 1)

# %%
# Tạo dataset cho LightGBM
train_data = lgb.Dataset(X_train_combined, label=y_train)
test_data = lgb.Dataset(X_test_combined, label=ytest, reference=train_data)

# %%
# Thiết lập các tham số cho LightGBM
params = {
    'objective': 'regression',
    'metric': 'rmse',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

# %%
# Huấn luyện mô hình LightGBM với early stopping
evals_result = {}
lgb_model = lgb.train(
    params,
    train_data,
    num_boost_round=100,
    valid_sets=[train_data, test_data],
    valid_names=['train', 'valid'],
    callbacks=[lgb.early_stopping(stopping_rounds=10), lgb.record_evaluation(evals_result)]
)

from sklearn.metrics import mean_absolute_error, mean_squared_error
# Dự đoán và đánh giá
y_pred = lgb_model.predict(X_test_combined, num_iteration=lgb_model.best_iteration)
# Hàm tính MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Hàm tính RMSE
def root_mean_squared_error(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Tính toán các chỉ số đánh giá
mse = mean_squared_error(ytest, y_pred)
rmse = root_mean_squared_error(ytest, y_pred)
mae = mean_absolute_error(ytest, y_pred)
mape = mean_absolute_percentage_error(ytest, y_pred)

# In ra các chỉ số đánh giá
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}%')
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000206 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 1435, number of used features: 1
# [LightGBM] [Info] Start training from score 0.498458
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [56]	train's rmse: 0.0230116	valid's rmse: 0.0178964
# Mean Squared Error (MSE): 0.0003202817984034461
# Root Mean Squared Error (RMSE): 0.017896418591535183
# Mean Absolute Error (MAE): 0.012792750514062713
# Mean Absolute Percentage Error (MAPE): 2.5163102127501005%

# %%
# 10. Hàm dự đoán 30 ngày tiếp theo
def predict_next_30_days(rnn_model, lgb_model, initial_data, time_step=100):
    predictions = []
    current_sequence = initial_data  # Lấy chuỗi dữ liệu cuối cùng làm dữ liệu khởi đầu

    for _ in range(30):
        # Reshape data for prediction
        current_sequence_reshaped = np.expand_dims(current_sequence, axis=0)

        # Predict features using RNN
        rnn_features = rnn_model.predict(current_sequence_reshaped)

        # Predict the next day's closing price using LightGBM
        next_close = lgb_model.predict(rnn_features, num_iteration=lgb_model.best_iteration)

        # Append the prediction
        predictions.append(next_close[0])

        # Update the sequence with the new prediction
        next_day = np.array([[next_close[0]]])
        current_sequence = np.vstack((current_sequence, next_day))

    return predictions

# Chuẩn bị dữ liệu ban đầu cho dự đoán 30 ngày tiếp theo
initial_data = df1.reshape(-1, 1)

# Dự đoán 30 ngày tiếp theo
next_30_days_predictions = predict_next_30_days(rnn_model, lgb_model, initial_data)
print("Dự đoán giá đóng cửa cho 30 ngày tiếp theo:", next_30_days_predictions)
# Out:
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 78ms/step
# Dự đoán giá đóng cửa cho 30 ngày tiếp theo: [0.45249918753216795, 0.45249918753216795, 0.4570866466553616, 0.4570866466553616, 0.4568570541862182, 0.4583765782750038, 0.46104482063453905, 0.4688412464872513, 0.4682903990763284, 0.47391762930487397, 0.47471403328003325, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523]

# %%
print(len(next_30_days_predictions))
# Out:
# 30

# %% [markdown]
# # Dự báo 60 ngày tiếp theo

# %%
def predict_next_days(rnn_model, lgb_model, initial_data, time_step=100, days_to_predict=60):
    predictions = []
    current_sequence = initial_data[:]  # Lấy chuỗi dữ liệu cuối cùng làm dữ liệu khởi đầu

    for _ in range(days_to_predict):
        # Reshape data for prediction
        current_sequence_reshaped = np.expand_dims(current_sequence, axis=0)

        # Predict features using RNN
        rnn_features = rnn_model.predict(current_sequence_reshaped)

        # Predict the next day's closing price using LightGBM
        next_close = lgb_model.predict(rnn_features)

        # Append the prediction
        predictions.append(next_close[0])

        # Update the sequence with the new prediction
        next_day = np.array([[next_close[0]]])
        current_sequence = np.vstack((current_sequence[1:], next_day))

    return predictions

# Chuẩn bị dữ liệu ban đầu cho dự đoán 60 ngày tiếp theo
initial_data = df1[:].reshape(-1, 1)

# Dự đoán 60 ngày tiếp theo
days_to_predict = 60
next_60_days_predictions = predict_next_days(rnn_model, lgb_model, initial_data, time_step, days_to_predict)
print("Dự đoán giá đóng cửa cho 60 ngày tiếp theo:", next_60_days_predictions)
# Out:
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 88ms/step
# Dự đoán giá đóng cửa cho 60 ngày tiếp theo: [0.45249918753216795, 0.45249918753216795, 0.4570866466553616, 0.4570866466553616, 0.4568570541862182, 0.4583765782750038, 0.46104482063453905, 0.4688412464872513, 0.4682903990763284, 0.47391762930487397, 0.47471403328003325, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523]

# %%
def predict_next_days(rnn_model, lgb_model, initial_data, time_step=100, days_to_predict=90):
    predictions = []
    current_sequence = initial_data[:]  # Lấy chuỗi dữ liệu cuối cùng làm dữ liệu khởi đầu

    for _ in range(days_to_predict):
        # Reshape data for prediction
        current_sequence_reshaped = np.expand_dims(current_sequence, axis=0)

        # Predict features using RNN
        rnn_features = rnn_model.predict(current_sequence_reshaped)

        # Predict the next day's closing price using LightGBM
        next_close = lgb_model.predict(rnn_features)

        # Append the prediction
        predictions.append(next_close[0])

        # Update the sequence with the new prediction
        next_day = np.array([[next_close[0]]])
        current_sequence = np.vstack((current_sequence[1:], next_day))

    return predictions

# Chuẩn bị dữ liệu ban đầu cho dự đoán 90 ngày tiếp theo
initial_data = df1[:].reshape(-1, 1)

# Dự đoán 90 ngày tiếp theo
days_to_predict = 90
next_90_days_predictions = predict_next_days(rnn_model, lgb_model, initial_data, time_step, days_to_predict)
print("Dự đoán giá đóng cửa cho 90 ngày tiếp theo:", next_90_days_predictions)
# Out:
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 79ms/step
# Dự đoán giá đóng cửa cho 90 ngày tiếp theo: [0.45249918753216795, 0.45249918753216795, 0.4570866466553616, 0.4570866466553616, 0.4568570541862182, 0.4583765782750038, 0.46104482063453905, 0.4688412464872513, 0.4682903990763284, 0.47391762930487397, 0.47471403328003325, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523, 0.47532118892259523]

# %%
len(next_90_days_predictions)
# Out:
# 90

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming 'df1', 'train_features_rnn', 'test_features_rnn', 'y_pred', 'next_30_days_predictions', 'next_60_days_predictions', 'next_90_days_predictions', and 'scaler' are already defined

# Plotting train data
start_idx, stop_idx = 0, len(train_features_rnn) + 100
train_data_index = pd.RangeIndex(start=start_idx, stop=stop_idx, step=1)
plt.plot(train_data_index, scaler.inverse_transform(df1[100: stop_idx + 100]), label='Train')

start_idx, stop_idx = stop_idx, stop_idx + len(test_features_rnn)
# Plotting test data
test_data_index = pd.RangeIndex(start=start_idx, stop=stop_idx, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_features_rnn), label='Test')

# Adjusting y_pred to have correct shape and length
test_data_index_pred = pd.RangeIndex(start=start_idx, stop=stop_idx, step=1)
plt.plot(test_data_index_pred, scaler.inverse_transform(np.array(y_pred).reshape(-1, 1)), label='Predict')

# Plotting next 30 days predictions
start_idx, stop_idx = stop_idx, stop_idx + len(next_30_days_predictions)
predict_30_data_index = pd.RangeIndex(start=start_idx, stop=stop_idx, step=1)
plt.plot(predict_30_data_index, scaler.inverse_transform(np.array(next_30_days_predictions).reshape(-1, 1)), label='Predict 30 days')

# Plotting next 60 days predictions
start_idx, stop_idx = stop_idx, stop_idx + len(next_60_days_predictions)
predict_60_data_index = pd.RangeIndex(start=start_idx, stop=stop_idx, step=1)
plt.plot(predict_60_data_index, scaler.inverse_transform(np.array(next_60_days_predictions).reshape(-1, 1)), label='Predict 60 days')

# Plotting next 90 days predictions
start_idx, stop_idx = stop_idx, stop_idx + len(next_90_days_predictions)
predict_90_data_index = pd.RangeIndex(start=start_idx, stop=stop_idx, step=1)
plt.plot(predict_90_data_index, scaler.inverse_transform(np.array(next_90_days_predictions).reshape(-1, 1)), label='Predict 90 days')

plt.legend(['Train', 'Test', 'Predict', 'Predict 30 days', 'Predict 60 days', 'Predict 90 days'])
plt.show()
